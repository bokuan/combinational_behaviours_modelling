# %%
import sys

# %%
sys.path.append("/mnt/vasp-got-da/scripts/common_libraries/adas_mtd/")

# %%
from src.db import db_helper_dsl3 as dbh

# %%
dbh.read_db_to_df('concatenated_files_metadata','da_concats')
# Out:
# Connection successful
#                          file_identifier  \
# 0       FM1073_20220812_114923_0-3_58xvv
# 1       FM1073_20220815_044631_0-3_18jrx
# 2      FM1073_20220815_114731_8-10_bognf
# 3       FM1073_20220816_034006_4-6_p0lhl
# 4       FM1073_20220816_034006_0-2_72tba
# ...                                  ...
# 48409  FM1073_20220903_162330_8-11_9dthl
# 48410   FM1073_20220905_110905_4-7_qbam6
# 48411   FM1073_20220905_130259_4-7_1hewh
# 48412   FM1073_20220905_145919_4-7_ydxqn
# 48413   FM1073_20220905_160045_0-3_4sc2o
#
#                                 filename_csv  \
# 0       FM1073_20220812_114923_0-3_58xvv.csv
# 1       FM1073_20220815_044631_0-3_18jrx.csv
# 2      FM1073_20220815_114731_8-10_bognf.csv
# 3       FM1073_20220816_034006_4-6_p0lhl.csv
# 4       FM1073_20220816_034006_0-2_72tba.csv
# ...                                      ...
# 48409  FM1073_20220903_162330_8-11_9dthl.csv
# 48410   FM1073_20220905_110905_4-7_qbam6.csv
# ...
